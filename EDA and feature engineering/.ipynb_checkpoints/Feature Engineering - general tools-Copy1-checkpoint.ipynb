# %% [markdown]
# ## imports

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# %matplotlib inline

# %%
pd.set_option('display.max_rows', 700, 'display.max_columns', 99)

# %% [markdown]
# ## Content

# %%
proc_usage = pd.read_csv('processed_pai_snapshot_c7_d2019-06-06_usage.csv')

# %%
proc_usage.is_sub_account.unique()
# Out:
# array([nan,  0.,  1.])

# %%
df = proc_usage.copy()
# df = proc_support.copy()

# %% [markdown]
# ##### Percentage 0 or NaN

# %%
zeros = ((df == 0).sum() * 100 / len(df)).sort_values(ascending=False)
zeros[zeros > 0]
# Out:
# percentile50                                             93.438077
# max_load_time                                            93.438077
# avg_load_time                                            93.438077
# percentile10                                             93.438077
# total_num_of_entries_per_day                             93.438077
# percentile80                                             93.438077
# percentile90                                             93.438077
# has_usage_data_today                                     40.158691
# daily_rows                                               40.158691
# days_since_last_usage                                    38.894456
# sso_configuration_enabled                                30.948555
# s3_configuration_enabled                                 29.682429
# query_api_enabled                                        27.719272
# is_sub_account                                           25.991189
# max_query_time                                           22.855810
# avg_query_time                                           22.855810
# api_access_enabled                                       16.257334
# daily_num_of_doc_dropped                                 16.113012
# engagement_sub_feature_insights_markers                  12.786044
# engagement_sub_feature_insights_cognitive_application    12.738147
# engagement_sub_feature_aggregationalerts                 12.653066
# engagement_sub_feature_optimizer                         12.590044
# engagement_sub_feature_volume_analysis                   12.576179
# engagement_sub_feature_timelion                          11.322657
# engagement_sub_feature_insights_general                  10.493279
# engagement_sub_feature_livetail                          10.288455
# num_of_page_reload                                        5.521418
# daily_gb_recived_with_sub_accounts                        3.347135
# total_num_of_alert_endpoint                               2.256843
# total_num_of_dashboards                                   2.096765
# total_number_of_elk_apps                                  2.010424
# daily_gb_indexed                                          1.741947
# daily_gb_indexed_with_sub_accounts                        1.738796
# total_num_of_alert_definitions                            1.592583
# total_num_of_visualizations                               1.438808
# engagement_sub_feature_any                                1.363181
# total_num_of_saved_searches                               0.918871
# daily_gb_received                                         0.760684
# daily_gb_archived                                         0.719719
# daily_num_of_success_searches                             0.494098
# daily_gb_indexed_all_clusters                             0.110290
# total_gb_used                                             0.042855
# daily_parent_remaining_gb                                 0.006302
# daily_gb_by_plan                                          0.003151
# daily_num_of_lags_latencies                               0.000630
# dtype: float64

# %%
nulls = (df.isnull().sum() * 100 / len(df)).sort_values(ascending=False)
nulls[nulls > 0]
# Out:
# first_log_timestamp                                      100.000000
# daily_num_of_times_logs_suspended_indexing                98.833450
# daily_num_of_lags_latencies                               98.002811
# total_num_of_optimizers_defined                           97.891891
# daily_num_of_failed_queries                               97.682656
# engagement_sub_feature_alerts                             97.298217
# daily_num_of_times_logs_suspended_archiving               96.906846
# daily_gb_indexed_all_clusters                             96.401404
# total_num_of_timeless_accounts                            95.881467
# sub_exception_type_key                                    94.401694
# num_of_exceptions                                         94.401694
# num_of_page_reload                                        94.401694
# account_key                                               93.438077
# engagement_sub_feature_any                                88.561381
# engagement_sub_feature_livetail                           87.924852
# total_num_of_alerts_on_agg_defined                        87.676542
# engagement_sub_feature_insights_general                   87.351345
# engagement_sub_feature_optimizer                          87.349455
# engagement_sub_feature_timelion                           87.248618
# engagement_sub_feature_volume_analysis                    87.207653
# engagement_sub_feature_insights_markers                   87.205133
# engagement_sub_feature_aggregationalerts                  87.205133
# engagement_sub_feature_insights_cognitive_application     87.198830
# total_number_of_elk_apps                                  83.875013
# daily_num_of_doc_dropped                                  83.186175
# total_num_of_sub_accounts                                 82.843962
# daily_num_of_success_searches                             80.672830
# query_status                                              80.556238
# total_num_of_dataparsing_defined                          79.377714
# total_num_of_tokens_defined                               77.038942
# total_gb_used                                             76.386027
# total_num_of_alert_endpoint                               75.197419
# total_num_of_saved_searches                               74.431063
# total_num_of_dashboards                                   74.336529
# total_num_of_visualizations                               74.336529
# total_number_of_shards                                    71.130564
# daily_num_of_incoming_logs                                70.848853
# daily_gb_archived                                         70.634576
# daily_gb_received                                         70.634576
# total_num_of_alert_definitions                            69.973467
# daily_gb_recived_with_sub_accounts                        68.035520
# daily_num_of_active_users                                 67.656753
# daily_parent_remaining_gb                                 64.994044
# daily_gb_by_plan                                          64.994044
# sso_configuration_enabled                                 64.613387
# is_sub_account                                            63.249576
# account_type                                              63.249576
# api_access_enabled                                        61.721906
# total_num_of_users                                        61.655102
# daily_gb_indexed_with_sub_accounts                        61.309738
# s3_configuration_enabled                                  61.309738
# daily_gb_indexed                                          61.309738
# query_api_enabled                                         61.309738
# max_query_time                                            57.700428
# avg_query_time                                            57.700428
# num_of_queries                                            57.700428
# dtype: float64

# %%
df.nunique().sort_values(ascending=False)
# Out:
# daily_num_of_incoming_logs                               45135
# daily_gb_indexed_with_sub_accounts                       30558
# total_gb_used                                            30098
# daily_gb_indexed                                         29982
# daily_gb_archived                                        25996
# daily_gb_recived_with_sub_accounts                       25521
# daily_gb_received                                        25024
# max_query_time                                           20990
# num_of_queries                                           16486
# avg_query_time                                           12865
# max_load_time                                             9980
# percentile90                                              9869
# percentile80                                              9752
# avg_load_time                                             9661
# percentile50                                              9109
# percentile10                                              7656
# daily_gb_indexed_all_clusters                             4368
# engagement_sub_feature_any                                2003
# total_num_of_users                                        1948
# daily_num_of_active_users                                 1252
# total_num_of_visualizations                               1197
# daily_num_of_lags_latencies                               1179
# total_num_of_saved_searches                               1115
# daily_num_of_doc_dropped                                  1113
# date                                                      1098
# days_since_last_usage                                     1006
# daily_gb_by_plan                                           960
# daily_parent_remaining_gb                                  890
# total_num_of_entries_per_day                               640
# total_num_of_dashboards                                    484
# account_key                                                474
# daily_num_of_success_searches                              423
# total_num_of_alert_definitions                             409
# total_number_of_shards                                     407
# num_of_exceptions                                          322
# pai_account_id                                             319
# total_num_of_tokens_defined                                161
# engagement_sub_feature_insights_general                    131
# total_num_of_alert_endpoint                                123
# daily_num_of_times_logs_suspended_archiving                121
# engagement_sub_feature_alerts                              108
# daily_num_of_times_logs_suspended_indexing                 101
# total_num_of_sub_accounts                                   92
# total_num_of_alerts_on_agg_defined                          85
# engagement_sub_feature_timelion                             80
# daily_rows                                                  79
# total_num_of_dataparsing_defined                            71
# engagement_sub_feature_livetail                             53
# daily_num_of_failed_queries                                 26
# total_number_of_elk_apps                                    26
# engagement_sub_feature_aggregationalerts                    16
# total_num_of_optimizers_defined                             10
# engagement_sub_feature_insights_cognitive_application        7
# engagement_sub_feature_volume_analysis                       7
# engagement_sub_feature_optimizer                             6
# sub_exception_type_key                                       5
# engagement_sub_feature_insights_markers                      5
# profile                                                      4
# num_of_page_reload                                           3
# total_num_of_timeless_accounts                               3
# sso_configuration_enabled                                    2
# s3_configuration_enabled                                     2
# has_usage_data_today                                         2
# query_status                                                 2
# query_api_enabled                                            2
# is_sub_account                                               2
# api_access_enabled                                           2
# account_type                                                 2
# stage                                                        1
# client_id                                                    1
# first_log_timestamp                                          0
# dtype: int64

# %%
cat_features = ['api_access_enabled', 'is_sub_account', 'query_api_enabled', 'query_status', 
                's3_configuration_enabled', 'sso_configuration_enabled', 'sub_exception_type_key']

# %%
old_name = ('is_sub_account', 'IsSubAccount')

# %%
features = ['max_query_time',
 'num_of_queries',
 'avg_query_time',
 'daily_gb_archived',
 'daily_gb_by_plan',
 'daily_gb_indexed_all_clusters',
 'daily_gb_indexed_with_sub_accounts',
 'daily_gb_received',
 'daily_gb_recived_with_sub_accounts',
 'daily_num_of_active_users',
 'daily_num_of_doc_dropped',
 'daily_num_of_failed_queries',
 'daily_num_of_incoming_logs',
 'daily_num_of_lags_latencies',
 'daily_num_of_success_searches',
 'daily_num_of_times_logs_suspended_archiving',
 'daily_num_of_times_logs_suspended_indexing',
 'daily_parent_remaining_gb',
 'total_gb_used',
 'total_num_of_alert_endpoint',
 'total_num_of_alerts_on_agg_defined',
 'total_num_of_dataparsing_defined',
 'total_num_of_optimizers_defined',
 'total_num_of_saved_searches',
 'total_num_of_sub_accounts',
 'total_num_of_timeless_accounts',
 'total_num_of_tokens_defined',
 'total_num_of_users',
 'total_num_of_visualizations',
 'total_number_of_elk_apps',
 'total_number_of_shards']

# %%
old_name = ('total_num_of_dashboards', 'TotalNumOfDashboards')

# %%
(df.isnull().sum() / len(df) * 100).plot(kind='bar', figsize=(15,2), title='Percentage of NaNs');

# %% [markdown]
# Plot of 'noise' in numeric columns - non-zero/null values:

# %%
df.select_dtypes(include=['int', 'float']).plot(subplots=True, layout=(9,3), figsize=(20, 30));

# %% [markdown]
# `Date_added` is usually (but not always) `date - 1`

# %%
diff = (processed.date - processed.date_added).dt.days
(diff != 1.0).sum() / len(diff)
# Out:
# 0.21143029531056212

# %% [markdown]
# `Created_timestamp` is exactly the same as date

# %%
nulls = (pd.isnull(usage) / len(usage)).sum().sort_values(ascending=False).to_dict()
zeros = ((usage == 0) / len(usage)).sum().sort_values(ascending=False).to_dict()

# %%
usage = pd.read_csv('usage.csv')
usage = usage.sort_values(by=['pai_account_id', 'date'])

# %% [markdown]
# numeric, few nans, lots of variance

# %%
df.describe()[df.describe().index.isin(['min', 'max', 'mean'])]
# Out:
#       avg_load_time  client_id  daily_gb_indexed  daily_rows  \
# mean   6.877414e+02        7.0          9.216814    0.877697
# min    0.000000e+00        7.0          0.000000    0.000000
# max    4.166430e+06        7.0      19050.000000  140.000000
#
#       days_since_last_usage  engagement_sub_feature_aggregationalerts  \
# mean              25.977242                                  0.017982
# min                0.000000                                  0.000000
# max              393.000000                                384.000000
#
#       engagement_sub_feature_alerts  engagement_sub_feature_any  \
# mean                       0.422014                  114.875989
# min                        0.000000                    0.000000
# max                     3267.000000               265140.000000
#
#       engagement_sub_feature_insights_cognitive_application  \
# mean                                           0.003209
# min                                            0.000000
# max                                           60.000000
#
#       engagement_sub_feature_insights_general  \
# mean                                 4.959185
# min                                  0.000000
# max                              62880.000000
#
#       engagement_sub_feature_insights_markers  \
# mean                                 0.004049
# min                                  0.000000
# max                                280.000000
#
#       engagement_sub_feature_livetail  engagement_sub_feature_optimizer  \
# mean                         0.252317                          0.002539
# min                          0.000000                          0.000000
# max                        966.000000                        102.000000
#
#       engagement_sub_feature_timelion  engagement_sub_feature_volume_analysis  \
# mean                         0.328349                                0.010005
# min                          0.000000                                0.000000
# max                       3400.000000                               66.000000
#
#       has_usage_data_today  max_load_time  num_of_exceptions  \
# mean              0.650431   1.177606e+03           7.254356
# min               0.000000   0.000000e+00           0.000000
# max               1.000000   4.166549e+06      162340.000000
#
#       num_of_page_reload  percentile10  percentile50  percentile80  \
# mean            0.005701  4.942682e+02  6.415199e+02  8.204955e+02
# min             0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# max            70.000000  4.166371e+06  4.166373e+06  4.166478e+06
#
#       percentile90  sub_exception_type_key  total_num_of_alert_definitions  \
# mean  9.235336e+02                0.304582                        8.863567
# min   0.000000e+00                0.000000                        0.000000
# max   4.166513e+06              315.000000                    13440.000000
#
#       total_num_of_dashboards  total_num_of_entries_per_day
# mean                11.312142                       5.73628
# min                  0.000000                       0.00000
# max              13580.000000                   12320.00000

# %%
df = df.sort_values(by=['pai_account_id', 'date'])

# %%
df = move_columns_to_front(df, ['pai_account_id', 'date'])

# %%
df.date = pd.to_datetime(df.date)

# %%
df['Conversation status'].value_counts()
# Out:
# Closed    11057
# Name: Conversation status, dtype: int64

# %%
df['Conversation rating requested'].value_counts()
# Out:
# no     6144
# yes    4913
# Name: Conversation rating requested, dtype: int64

# %%
df.Channel.value_counts()
# Out:
# Desktop    10393
# Unknown      604
# Email         60
# Name: Channel, dtype: int64

# %%
df.Type.value_counts()
# Out:
# User    11055
# Lead        2
# Name: Type, dtype: int64

# %%
df['Teammate replies'].value_counts().head()
# Out:
# 2    1076
# 3    1065
# 4     997
# 5     873
# 6     769
# Name: Teammate replies, dtype: int64

# %%
df.Closed.hist();

# %%
df.Reopened.value_counts()
# Out:
# 0     9945
# 1      808
# 2      113
# 3      105
# 7       32
# 10      32
# 5       11
# 4       11
# Name: Reopened, dtype: int64

# %%
df['Inbound/Outbound'].value_counts()
# Out:
# Inbound     10453
# Outbound      604
# Name: Inbound/Outbound, dtype: int64

# %%
df.location.value_counts().head()
# Out:
# Israel            3562
# United States     2749
# India             1591
# United Kingdom     961
# Slovenia           418
# Name: location, dtype: int64

# %%
df.Source.value_counts()
# Out:
# Manual message          339
# Visitor auto message    263
# User auto message         2
# Name: Source, dtype: int64

# %% [markdown]
# Notes<br>
# Channel + Type are very one-sided, Reopened is 89% 0s, source is 94.5% NaN<br>
# What are closed values?
# Teammate replies - sum?

# %%
df.query("pai_account_id=='0011r00001kSV2X'")
# Out:
# Empty DataFrame
# Columns: [pai_account_id, date, Channel, client_id, Closed, Conversation rating requested, Conversation status, Inbound/Outbound, last_modified_date, location, profile, Reopened, Source, stage, Teammate replies, Conversation ID, ticket_open_time, ticket_solved_time, Time to first reply (seconds), Time to last close (seconds), Type]
# Index: []

# %%
matrix = pd.read_csv('fe_matrix_and_target_c7_paying-all_d2019-05-27.csv')

# %%
(matrix.iloc[:, 4:-4] == '0').any()
# Out:
# TeammateRepliesFe                              False
# ClosedFe                                       False
# TicketsOpenedFe                                False
# TicketsOpenedFe.conv_rating_requested.no       False
# TicketsOpenedFe.conv_rating_requested.yes      False
# TicketsOpenedFe.inbound_outbound.Inbound       False
# TicketsOpenedFe.inbound_outbound.Outbound      False
# TicketsOpenedAndClosedFe                       False
# TicketsOpenedAndClosedInSpecialTimeWindowFe    False
# TicketsOpenedInSpecialTimeWindowFe             False
# dtype: bool

# %%
df.ticket_open_time = pd.to_datetime(df.ticket_open_time)
df.ticket_solved_time = pd.to_datetime(df.ticket_solved_time)

# %%
df.date.min(), df.date.max()
# Out:
# ('2018-01-01', '2018-12-31')

# %%
df.head(20)
# Out:
#     channel  client_id  closed conv_rating_requested conv_status        date  \
# 0   Desktop          7       2                    no      Closed  2018-01-16
# 1   Desktop          7       2                    no      Closed  2018-01-17
# 2   Desktop          7       3                    no      Closed  2018-01-30
# 3   Desktop          7       1                    no      Closed  2018-02-04
# 4   Desktop          7       4                    no      Closed  2018-02-05
# 5   Desktop          7       1                    no      Closed  2018-04-26
# 6   Unknown          7       2                    no      Closed  2018-02-28
# 7   Unknown          7       2                    no      Closed  2018-02-28
# 8   Unknown          7       2                    no      Closed  2018-02-28
# 9   Unknown          7       2                    no      Closed  2018-02-28
# 10  Unknown          7       2                    no      Closed  2018-02-28
# 11  Unknown          7       2                    no      Closed  2018-02-28
# 12  Unknown          7       2                    no      Closed  2018-02-28
# 13  Unknown          7       2                    no      Closed  2018-02-28
# 14  Unknown          7       2                    no      Closed  2018-02-28
# 15  Unknown          7       2                    no      Closed  2018-02-28
# 16  Unknown          7       2                    no      Closed  2018-02-28
# 17  Unknown          7       2                    no      Closed  2018-02-28
# 18  Unknown          7       2                    no      Closed  2018-02-28
# 19  Unknown          7       2                    no      Closed  2018-02-28
#
#    inbound_outbound   last_modified_date   pai_account_id profile  reopened  \
# 0           Inbound  2018-01-17 09:38:36  0011r00001l1P78     smb         0
# 1           Inbound  2018-01-17 09:02:42  0011r00001l1P78     smb         0
# 2           Inbound  2018-01-30 11:11:36  0011r00001l1P78     smb         1
# 3           Inbound  2018-02-04 09:51:57  0011r00001l1P78     smb         0
# 4           Inbound  2018-04-17 08:08:02  0011r00001l1P78     smb         2
# 5           Inbound  2018-04-26 07:20:01  0011r00001l1P78     smb         0
# 6          Outbound  2018-02-28 07:29:39  0011r00001l1Tjh     smb         0
# 7          Outbound  2018-02-28 07:29:39  0011r00001l1Tjh     smb         0
# 8          Outbound  2018-02-28 07:29:39  0011r00001l1Tjh     smb         0
# 9          Outbound  2018-02-28 07:29:39  0011r00001l1Tjh     smb         0
# 10         Outbound  2018-02-28 07:29:39  0011r00001l1Tjh     smb         0
# 11         Outbound  2018-02-28 07:29:39  0011r00001l1Tjh     smb         0
# 12         Outbound  2018-02-28 07:29:39  0011r00001l1Tjh     smb         0
# 13         Outbound  2018-02-28 07:29:39  0011r00001l1Tjh     smb         0
# 14         Outbound  2018-02-28 07:29:39  0011r00001l1Tjh     smb         0
# 15         Outbound  2018-02-28 07:29:39  0011r00001l1Tjh     smb         0
# 16         Outbound  2018-02-28 07:29:39  0011r00001l1Tjh     smb         0
# 17         Outbound  2018-02-28 07:29:39  0011r00001l1Tjh     smb         0
# 18         Outbound  2018-02-28 07:29:39  0011r00001l1Tjh     smb         0
# 19         Outbound  2018-02-28 07:29:39  0011r00001l1Tjh     smb         0
#
#      stage  teammate-replies      conv_id     ticket_open_time  \
# 0   paying                 9  14110455732  2018-01-16 15:41:55
# 1   paying                21  14118686726  2018-01-17 04:35:49
# 2   paying                 2  14357886923  2018-01-30 10:06:52
# 3   paying                 3  14443768114  2018-02-04 09:17:37
# 4   paying                 5  14454359899  2018-02-05 03:42:09
# 5   paying                 2  15987416549  2018-04-26 07:03:48
# 6   paying                 4  14904118932  2018-02-28 02:37:23
# 7   paying                 4  14904118932  2018-02-28 02:37:23
# 8   paying                 4  14904118932  2018-02-28 02:37:23
# 9   paying                 4  14904118932  2018-02-28 02:37:23
# 10  paying                 4  14904118932  2018-02-28 02:37:23
# 11  paying                 4  14904118932  2018-02-28 02:37:23
# 12  paying                 4  14904118932  2018-02-28 02:37:23
# 13  paying                 4  14904118932  2018-02-28 02:37:23
# 14  paying                 4  14904118932  2018-02-28 02:37:23
# 15  paying                 4  14904118932  2018-02-28 02:37:23
# 16  paying                 4  14904118932  2018-02-28 02:37:23
# 17  paying                 4  14904118932  2018-02-28 02:37:23
# 18  paying                 4  14904118932  2018-02-28 02:37:23
# 19  paying                 4  14904118932  2018-02-28 02:37:23
#
#      ticket_solved_time  time_to_first_reply  time_to_last_close  type
# 0   2018-01-17 09:38:36                 29.0             64601.0  User
# 1   2018-01-17 09:02:42                 60.0             15633.0  User
# 2   2018-01-30 11:11:36                254.0              3884.0  User
# 3   2018-02-04 09:51:57                 80.0              1784.0  User
# 4   2018-04-17 08:08:02                327.0           6146753.0  User
# 5   2018-04-26 07:20:01                 96.0               972.0  User
# 6   2018-02-28 07:29:39                779.0              2366.0  User
# 7   2018-02-28 07:29:39                779.0              2366.0  User
# 8   2018-02-28 07:29:39                779.0              2366.0  User
# 9   2018-02-28 07:29:39                779.0              2366.0  User
# 10  2018-02-28 07:29:39                779.0              2366.0  User
# 11  2018-02-28 07:29:39                779.0              2366.0  User
# 12  2018-02-28 07:29:39                779.0              2366.0  User
# 13  2018-02-28 07:29:39                779.0              2366.0  User
# 14  2018-02-28 07:29:39                779.0              2366.0  User
# 15  2018-02-28 07:29:39                779.0              2366.0  User
# 16  2018-02-28 07:29:39                779.0              2366.0  User
# 17  2018-02-28 07:29:39                779.0              2366.0  User
# 18  2018-02-28 07:29:39                779.0              2366.0  User
# 19  2018-02-28 07:29:39                779.0              2366.0  User

# %%
support.Closed.value_counts()
# Out:
# 1     52504
# 2     16696
# 3      5910
# 4      2991
# 0      1665
# 5      1517
# 6       696
# 7       366
# 8       182
# 10      151
# 9        88
# 13       82
# 16       82
# 12       79
# 11       70
# 14       33
# 19       33
# 32       32
# 20       25
# 24        5
# 27        4
# 15        3
# 37        3
# 17        1
# 18        1
# 22        1
# 31        1
# Name: Closed, dtype: int64

# %%
nulls = (df.isnull().sum() * 100 / len(df)).sort_values(ascending=False)
nulls[nulls > 0]
# Out:
# Source                           94.537397
# location                          5.607308
# Time to first reply (seconds)     3.346296
# Time to last close (seconds)      1.157638
# dtype: float64

# %%
old_usage = pd.read_csv('APPSFLYER_cleaned_usage_APPSFLYER.csv')
old_usage = old_usage.sort_values(by=['date'])
old_usage = old_usage[sorted(list(old_usage))]
# Out:
# /Users/joshfriedlander/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (10,29,46) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
